# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter("ignore")

# %%
train=pd.read_csv("/Users/shashikanthbokka/Desktop/2-YEAR/minor project/titanic/train.csv")
test=pd.read_csv("/Users/shashikanthbokka/Desktop/2-YEAR/minor project/titanic/test.csv")

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
test.tail()
# Out:
#      PassengerId  Pclass                          Name     Sex   Age  SibSp  \
# 413         1305       3            Spector, Mr. Woolf    male   NaN      0
# 414         1306       1  Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415         1307       3  Saether, Mr. Simon Sivertsen    male  38.5      0
# 416         1308       3           Ware, Mr. Frederick    male   NaN      0
# 417         1309       3      Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked
# 413      0           A.5. 3236    8.0500   NaN        S
# 414      0            PC 17758  108.9000  C105        C
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416      0              359309    8.0500   NaN        S
# 417      1                2668   22.3583   NaN        C

# %%
test.shape
# Out:
# (418, 11)

# %%
train.shape
# Out:
# (891, 12)

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# here we are checking the duplicates and droping the values using the drop duplicate attribute.
train.drop_duplicates()
train.duplicated().sum()
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.drop_duplicates()
test.duplicated().sum()
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# for checking the unique values in the column
train.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
train_num=train[['Age','SibSp','Parch','Fare']]
train_cat=train[['Survived','Pclass','Sex','Ticket','Cabin','Embarked']]
print(train_num)
# Out:
#       Age  SibSp  Parch     Fare
# 0    22.0      1      0   7.2500
# 1    38.0      1      0  71.2833
# 2    26.0      0      0   7.9250
# 3    35.0      1      0  53.1000
# 4    35.0      0      0   8.0500
# ..    ...    ...    ...      ...
# 886  27.0      0      0  13.0000
# 887  19.0      0      0  30.0000
# 888   NaN      1      2  23.4500
# 889  26.0      0      0  30.0000
# 890  32.0      0      0   7.7500
#
# [891 rows x 4 columns]

# %%
# here the bin is the number of the bars to be appeared in the histogram
plt.hist(train_num['Age'],bins=10)
plt.title("Age")
plt.show()

# %%
sns.histplot(train_num['Age'],bins=10)
plt.title("Age")
plt.show()

# %%
sns.histplot(train_num["SibSp"],bins=10)
plt.title('SibSp')
plt.show()

# %%
sns.histplot(train_num["Parch"],bins=10)
plt.title('Parent/Child')
plt.show()

# %%
sns.histplot(train_num["Fare"],bins=10)
plt.title('Fare')
plt.show()

# %%
train_cat['Survived'].unique()
# Out:
# array([0, 1])

# %%
train_cat["Survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
# countplot is used to plot the counting of a categorical data in different colours
sns.countplot(train_cat["Survived"],data=train_cat,palette='hls')
plt.xticks(rotation=90)
plt.title("Survived")
plt.show()

# %%
sns.countplot(train_cat["Survived"],palette='hls')
# here the rotaion is for the label in x-axis to rotate by 90 degrees
plt.xticks(rotation=90)
plt.title("Survived")
plt.show()

# %%
for i in train_cat.columns:
    plt.figure(figsize=(15,6))
    sns.countplot(train_cat[i],data=train_cat,palette='hls')
    plt.xticks(rotation=90)
    plt.show()

# %%
sns.pairplot(train_num)
plt.show()

# %%
# this gives the plots of each category with all other categories 
sns.pairplot(train_num)
plt.show()

# %%
# this corr() gives the correlation between the attributes .this gives the attributes are directly propotional or inverserly propostional or nothing
print(train_num.corr())
# Out:
#             Age     SibSp     Parch      Fare
# Age    1.000000 -0.308247 -0.189119  0.096067
# SibSp -0.308247  1.000000  0.414838  0.159651
# Parch -0.189119  0.414838  1.000000  0.216225
# Fare   0.096067  0.159651  0.216225  1.000000

# %%
plt.figure(figsize=(15,15))
cmap=sns.diverging_palette(250,10,s=80,l=55,n=9,as_cmap=True)
sns.heatmap(train_num.corr(),annot=True,cmap=cmap,center=0)
plt.show()

# %%
pd.pivot_table(train,index='Survived',values=['Age','SibSp','Parch','Fare'])
# Out:
#                 Age       Fare     Parch     SibSp
# Survived
# 0         30.626179  22.117887  0.329690  0.553734
# 1         28.343690  48.395408  0.464912  0.473684

# %%
train_cat["Survived"].value_counts(normalize=True)
# Out:
# 0    0.616162
# 1    0.383838
# Name: Survived, dtype: float64

# %%
Survived=train_cat["Survived"].value_counts(normalize=True)
survived=pd.DataFrame(Survived)
display(survived)
# Out:
#    Survived
# 0  0.616162
# 1  0.383838

# %%
survived=survived.reset_index()
display(survived)
# Out:
#    index  Survived
# 0      0  0.616162
# 1      1  0.383838

# %%
#fixing column names
Survived=survived.rename(columns={'index':'Survived', "Survived":'% of Survivors'})

Survived['% of Survivors']=Survived['% of Survivors']*100
display(Survived)

Survived['% of Survivors']=np.round(Survived['% of Survivors'],2)
display(Survived)
# Out:
#    Survived  % of Survivors
# 0         0       61.616162
# 1         1       38.383838
#    Survived  % of Survivors
# 0         0           61.62
# 1         1           38.38

# %%
plt.figure(figsize=(6,5))
sns.barplot(x='Survived',y='% of Survivors', data= Survived)
plt.title("Percent of Survival rate")
plt.show()

# %%
Pclass=train_cat["Pclass"].value_counts(normalize=True)
Pclass=pd.DataFrame(Pclass)
Pclass=Pclass.reset_index()
# fixing column names
Pclass=Pclass.rename(columns={"index":"Class","Pclass":"% of passengers"})
Pclass=Pclass.sort_values(by="Class")
Pclass["% of passengers"]=Pclass["% of passengers"]*100
Pclass["% of passengers"]=np.round(Pclass["% of passengers"],2)
display(Pclass)
# Out:
#    Class  % of passengers
# 1      1            24.24
# 2      2            20.65
# 0      3            55.11

# %%
plt.figure(figsize=(6,5))
sns.barplot(x='Class',y='% of passengers', data= Pclass)
plt.title("Percentage of passengers")
plt.show()

# %% [markdown]
# # DAY-3 FROM HERE

# %%
sex=train_cat["Sex"].value_counts(normalize=True)
sex=pd.DataFrame(sex)
sex=sex.reset_index()
# fixing columns names
sex=sex.rename(columns={"index":"sex","Sex":"% of passengers"})
sex=sex.sort_values(by='sex')
sex["% of passengers"]=sex["% of passengers"]*100
sex["% of passengers"]=np.round(sex["% of passengers"],2)
display(sex)
# Out:
#       sex  % of passengers
# 1  female            35.24
# 0    male            64.76

# %%
plt.figure(figsize=(6,5))
sns.barplot(x='sex',y='% of passengers',data=sex)
plt.title("percentage of gender")
plt.plot()
# Out:
# []

# %%
# so here we are using this to train our model
train=train[['Survived','Pclass','Sex','Age','Fare']]
train=pd.DataFrame(train)
train.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare
# 0         0       3    male  22.0   7.2500
# 1         1       1  female  38.0  71.2833
# 2         1       3  female  26.0   7.9250
# 3         1       1  female  35.0  53.1000
# 4         0       3    male  35.0   8.0500

# %%
train.tail()
# Out:
#      Survived  Pclass     Sex   Age   Fare
# 886         0       2    male  27.0  13.00
# 887         1       1  female  19.0  30.00
# 888         0       3  female   NaN  23.45
# 889         1       1    male  26.0  30.00
# 890         0       3    male  32.0   7.75

# %%
train.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# Fare          0
# dtype: int64

# %%
# here we are considering gender for grouping and dividing them and showing the mean age of the each gender 
# we are considering the age and grouping them 
train.groupby('Sex')['Age'].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
test_x=test[['Pclass','Sex','Age','Fare']]
display(test_x)
# Out:
#      Pclass     Sex   Age      Fare
# 0         3    male  34.5    7.8292
# 1         3  female  47.0    7.0000
# 2         2    male  62.0    9.6875
# 3         3    male  27.0    8.6625
# 4         3  female  22.0   12.2875
# ..      ...     ...   ...       ...
# 413       3    male   NaN    8.0500
# 414       1  female  39.0  108.9000
# 415       3    male  38.5    7.2500
# 416       3    male   NaN    8.0500
# 417       3    male   NaN   22.3583
#
# [418 rows x 4 columns]

# %%
# here we are considering gender for grouping and dividing them and showing the mean age of the each gender 
# we are considering the age and grouping them 
test_x.groupby('Sex')['Age'].mean()
# Out:
# Sex
# female    30.272362
# male      30.272732
# Name: Age, dtype: float64

# %%
# recreating the age column to fill the empty spaces in age column with the mean values
# fillna is fill not available values
# we are grouping and replacing na with the respective gender's mean value
train['Age']=train.groupby('Sex')['Age'].transform(lambda x:x.fillna(x.mean()))

# %%
# recreating the age column to fill the empty spaces in age column with the mean values
# fillna is fill not available values
# we are grouping and replacing na with the respective gender's mean value

test_x['Age']=test_x.groupby('Sex')['Age'].transform(lambda x:x.fillna(x.mean()))

# we are filling the empty spaces in fare with the mean fare price

test_x['Fare'].fillna(test_x['Fare'].mean(),inplace=True)

# %%
train.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# Fare        0
# dtype: int64

# %% [markdown]
# # ML STARTS FROM HERE

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# changing categorical columns to numerical
le=LabelEncoder()

# %%
# here we are converting the gender string values to numerical values using label encoding
train['Sex']= le.fit_transform(train.Sex)
train.head()
# Out:
#    Survived  Pclass  Sex   Age     Fare
# 0         0       3    1  22.0   7.2500
# 1         1       1    0  38.0  71.2833
# 2         1       3    0  26.0   7.9250
# 3         1       1    0  35.0  53.1000
# 4         0       3    1  35.0   8.0500

# %%
# having full of numerical valuess is very use full than objects and strings
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    int64
#  3   Age       891 non-null    float64
#  4   Fare      891 non-null    float64
# dtypes: float64(2), int64(3)
# memory usage: 34.9 KB

# %%
# here we are assigning to x and y axis and the value we want to predict should be on y-axis
# so survived is on y axis
x=train[['Pclass','Sex','Age','Fare']]
y=train['Survived']

# %%
# converting the categorical sex to numerical values
test_x['Sex']=le.fit_transform(test_x.Sex)
test_x.head()
# Out:
#    Pclass  Sex   Age     Fare
# 0       3    1  34.5   7.8292
# 1       3    0  47.0   7.0000
# 2       2    1  62.0   9.6875
# 3       3    1  27.0   8.6625
# 4       3    0  22.0  12.2875

# %%
x.shape
# Out:
# (891, 4)

# %%
x.isnull().sum()
# Out:
# Pclass    0
# Sex       0
# Age       0
# Fare      0
# dtype: int64

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Pclass  891 non-null    int64
#  1   Sex     891 non-null    int64
#  2   Age     891 non-null    float64
#  3   Fare    891 non-null    float64
# dtypes: float64(2), int64(2)
# memory usage: 28.0 KB

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split
# y_train=train['Survived']
display(y_train)
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
sc=StandardScaler()
x=sc.fit_transform(x)
test_x=sc.fit_transform(test_x)

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
# importing the decision tree and fitting the data x and y_train to the model
model=DecisionTreeClassifier()
model.fit(x,y_train)
# Out:
# DecisionTreeClassifier()

# %%
# we are predicting y using test_x data from the model
y_pred=model.predict(test_x)

# %%
from sklearn.metrics import classification_report

# %%
gender_sub_data=pd.read_csv("/Users/shashikanthbokka/Desktop/2-YEAR/minor project/titanic/gender_submission.csv")

# %%
test_y=gender_sub_data['Survived']

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84       266
#            1       0.73      0.70      0.72       152
#
#     accuracy                           0.80       418
#    macro avg       0.78      0.78      0.78       418
# weighted avg       0.80      0.80      0.80       418

# %%
print('Training Accuracy', model.score(x, y_train))
print('Testing Accuracy',model.score(test_x,test_y))
# Out:
# Training Accuracy 0.9797979797979798
# Testing Accuracy 0.7990430622009569

# %%
from sklearn import tree
plt.figure(figsize=(10,15))
tree.plot_tree(model,filled=True)
plt.show()

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression(random_state=0)
classifier.fit(x,y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred=classifier.predict(test_x)

# %%
print("Training Accuracy:",classifier.score(x,y_train))
print("Testing Accuracy:",classifier.score(test_x,test_y))
# Out:
# Training Accuracy: 0.7991021324354658
# Testing Accuracy: 0.9569377990430622

# %% [markdown]
# # Random Forest Classifier

# %%
# fitting decision tree classifier to the training set
# n_estimators is the requried number of trees in the random forest
# the default value is 10.we can choose any number but to take 
# care of the overfitting issue
# critrion = it is a function to analyse the accuarcy of the random forest
# here we have taken the entropy for the information gain

from sklearn.ensemble import RandomForestClassifier
classifier1=RandomForestClassifier(n_estimators=10,criterion='entropy')
classifier1.fit(x,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10)

# %%
print("Training Accuracy:",classifier1.score(x,y_train))
print("Testing Accuracy:",classifier1.score(test_x,test_y))
# Out:
# Training Accuracy: 0.9652076318742986
# Testing Accuracy: 0.8397129186602871
